# %% [markdown]
# In this assignment we'll ask you to plot multiple variables.
#
# You will use what you find in this assignment to answer the questions in the quiz that follows. It may be useful to keep this notebook side-by-side with this week's quiz on your screen.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 100)
sns.set_theme(rc={'figure.dpi':150,'figure.figsize':(6,4)})
path = "Cartwheeldata.csv"

# %%
# First, you must import the cartwheel data from the path given above
df = pd.read_csv(path)

# %%
# Next, look at the 'head' of our DataFrame 'df'. 
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %% [markdown]
# If you can't remember a function, open a previous notebook or video as a reference, or use your favorite search engine to look for a solution.

# %% [markdown]
# ## Scatter plots

# %% [markdown]
# First, let's looks at two variables that we expect to have a strong relationship, 'Height' and 'Wingspan'.

# %%
# Make a Seaborn scatter plot with x = height and y = wingspan using sns.scatterplot(x, y)
sns.regplot(x = 'Height', y = 'Wingspan' , data = df)
# Out:
# <Axes: xlabel='Height', ylabel='Wingspan'>

# %% [markdown]
# How would you describe the relationship between 'Height' and 'Wingspan'?
# Questions you can ask:
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# > Yes, the points follow a roughly straight line
# >
# > There are some outliers
# >
# > Different
# >
# >Is it linear? Wingspan and height seem to have a positive linear relationship. As the height increases, the wingspan of the individual seems to increase as well.  There seems to be few outliers.

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance
# Are their ranges similar or different? Different 
a = df['Height'].quantile(0.75) - df['Height'].quantile(0.25)
print("Range for Height:", a)
b = df['Wingspan'].quantile(0.75) - df['Wingspan'].quantile(0.25)
print("Range for Wingspan:", b)
# Out:
# Range for Height: 7.0
# Range for Wingspan: 9.0

# %% [markdown]
# Now let's look at two variables that we don't yet assume have a strong relationship, 'Wingspan' and 'CWDistance'

# %%
sns.regplot(x = 'Wingspan', y = 'CWDistance' , data = df);

# %% [markdown]
# How would you describe the relationship between 'Wingspan' and 'CWDistance'?
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# > The relationship between 'Wingspan' and 'CWDistance' is hard to tell with a scatter plot. It seems that there are some outliers.

# %% [markdown]
# Let makes the same plot as above, but now include 'Gender' as the color scheme by including the argument
# ```
# hue=df['Gender']
# ```
# in the Seaborn function

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance, and hue = gender
sns.lmplot(x = "Wingspan", y = "CWDistance", data = df, hue = "Gender")

# %% [markdown]
# Does does this new information on the plot change your interpretation of the relationship between 'Wingspan' and 'CWDistance'?

# %% [markdown]
# > Males seems to have a stronger linear relationship between Wingspan and Cartwheel distance compared to that of females.

# %% [markdown]
# ## Barcharts
# Now lets plot barplots of 'Glasses'

# %%
# Make a Seaborn barplot with x = glasses and y = cartwheel distance
sns.barplot(data = df, x = "Glasses", y="CWDistance")
# Out:
# <Axes: xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# What can you say about the relationship of 'Glasses' and 'CWDistance'?

# %% [markdown]
# >Individuals who didnot were glasses coverd more distance while doing the cartwheel.

# %%
# Make the same Seaborn boxplot as above, but include gender for the hue argument
sns.barplot(data = df, x = "Glasses", y="CWDistance", hue = "Gender")
# Out:
# <Axes: xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# How does this new plot change your interpretation about the relationship of 'Glasses' and 'CWDistance'?

# %% [markdown]
# > The distance covered by cartwheel is larger for females who did not wear glasses whereas the distance covered by cartwheel for males is lower for those who did wear glasses.
